# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (15, 10)

# %%
df = pd.read_excel('data/indicateur_victimation_et_insécurité.xlsx', engine='openpyxl', skiprows=7, nrows=19)
df
# Out:
#                                   INDICATEURS/PERIODE       2006       2007  \
# 0   nombre de cambriolages et tentatives de cambri...   451000.0   438000.0
# 1   nombre de vols sans effraction visant les rési...   280000.0   335000.0
# 2     nombre d'actes de vandalisme contre le logement   949000.0  1154000.0
# 3     nombre de vols et tentatives de vols de voiture   570000.0   482000.0
# 4   nombre de vols et tentatives de vols de deux-r...   145000.0   117000.0
# 5        nombre de vols et tentatives  de vol de vélo   334000.0   339000.0
# 6       nombre de vols d'objet dans ou sur la voiture        NaN        NaN
# 7      nombre d'actes de vandalisme contre la voiture  1602000.0  2029000.0
# 8   nombre de victimes de vols ou tentatives de vo...  1105000.0   960000.0
# 9   nombre de victimes de vols ou tentatives de vo...   361000.0   323000.0
# 10  nombre de victimes de débit frauduleux sur leu...        NaN        NaN
# 11  nombre de victimes de violences physiques hors...   776000.0   842000.0
# 12  nombre de victimes de violences sexuelles hors...        NaN        NaN
# 13  nombre de victimes de violences physiques et/o...        NaN        NaN
# 14              nombre de victimes d'actes de menaces  1898000.0  1849000.0
# 15  nombre de victimes d'injures en dehors du ména...  5218000.0  5397000.0
# 16  nombre de personnes âgées de 14 ans ou  plus s...        NaN  5492000.0
# 17  nombre de personnes âgées de 14 ans ou  plus s...        NaN  4040000.0
# 18  nombre de personnes âgées de 14 ans ou  plus r...        NaN  6130000.0
#
#          2008       2009     2010     2011     2012     2013     2014  \
# 0    386000.0   413000.0   457000   554000   559000   584000   602000
# 1    275000.0   323000.0   302000   296000   287000   254000   307000
# 2   1233000.0  1507000.0  1420000  1453000  1241000  1283000  1273000
# 3    456000.0   397000.0   395000   294000   270000   294000   242000
# 4    102000.0   164000.0    96000   142000    77000   134000    83000
# 5    333000.0   348000.0   318000   314000   314000   401000   405000
# 6    971000.0  1011000.0   874000   830000   854000   833000   813000
# 7   1971000.0  2067000.0  1935000  1691000  1731000  1693000  1672000
# 8    993000.0  1089000.0   940000   847000   858000   937000   969000
# 9    241000.0   291000.0   300000   274000   306000   372000   195000
# 10        NaN        NaN   500000   632000   743000   851000   883000
# 11   887000.0   874000.0   695000   695000   754000   702000   720000
# 12   142000.0   203000.0    93000   142000   146000   121000   189000
# 13   417000.0   447000.0   330000   397000   425000   349000   446000
# 14  2061000.0  1715000.0  1704000  1611000  1637000  1774000  1938000
# 15  5234000.0  5001000.0  5019000  4565000  5309000  4782000  4990000
# 16  4875000.0  5301000.0  5500000  5522000  5801000  6033000  5800000
# 17  3330000.0  3670000.0  4160000  4220000  4460000  4760000  4620000
# 18  5754000.0  5718000.0  5512000  5975000  5826000  5791000  5889000
#
#        2015     2016     2017     2018       2019       2020       2021
# 0    536000   507000   624000   557000        NaN   379000.0        NaN
# 1    320000   277000   289000   331000        NaN   181000.0        NaN
# 2   1307000  1117000   966000  1184000        NaN   980000.0        NaN
# 3    263000   263000   232000   209000        NaN   125000.0        NaN
# 4    126000    93000    72000    44000        NaN        NaN        NaN
# 5    349000   387000   403000   361000        NaN   241000.0        NaN
# 6    663000   650000   775000   663000        NaN   465000.0        NaN
# 7   1602000  1458000  1653000  1337000        NaN   779000.0        NaN
# 8    798000   753000  1096000   967000        NaN   554000.0        NaN
# 9    245000   186000   210000   166000        NaN   122000.0        NaN
# 10  1102000  1210000  1219000  1260000        NaN  1305000.0        NaN
# 11   775000   610000   672000   710000        NaN   441000.0        NaN
# 12   135000   200000   276000   196000        NaN        NaN        NaN
# 13   317000   285000   408000   359000        NaN        NaN        NaN
# 14  1694000  1811000  1960000  1805000        NaN  1516000.0        NaN
# 15  5240000  4994000  5334000  4882000        NaN  4193000.0        NaN
# 16  5663000  5473000  5709000  6207000  5925000.0        NaN  5803000.0
# 17  4270000  3910000  4230000  4460000  3970000.0        NaN  3694000.0
# 18  5556000  5289100  5352000  5807000  5723000.0        NaN  5525000.0

# %%
getYears = df[['INDICATEURS/PERIODE', 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]]
getYears
# Out:
#                                   INDICATEURS/PERIODE     2010     2011  \
# 0   nombre de cambriolages et tentatives de cambri...   457000   554000
# 1   nombre de vols sans effraction visant les rési...   302000   296000
# 2     nombre d'actes de vandalisme contre le logement  1420000  1453000
# 3     nombre de vols et tentatives de vols de voiture   395000   294000
# 4   nombre de vols et tentatives de vols de deux-r...    96000   142000
# 5        nombre de vols et tentatives  de vol de vélo   318000   314000
# 6       nombre de vols d'objet dans ou sur la voiture   874000   830000
# 7      nombre d'actes de vandalisme contre la voiture  1935000  1691000
# 8   nombre de victimes de vols ou tentatives de vo...   940000   847000
# 9   nombre de victimes de vols ou tentatives de vo...   300000   274000
# 10  nombre de victimes de débit frauduleux sur leu...   500000   632000
# 11  nombre de victimes de violences physiques hors...   695000   695000
# 12  nombre de victimes de violences sexuelles hors...    93000   142000
# 13  nombre de victimes de violences physiques et/o...   330000   397000
# 14              nombre de victimes d'actes de menaces  1704000  1611000
# 15  nombre de victimes d'injures en dehors du ména...  5019000  4565000
# 16  nombre de personnes âgées de 14 ans ou  plus s...  5500000  5522000
# 17  nombre de personnes âgées de 14 ans ou  plus s...  4160000  4220000
# 18  nombre de personnes âgées de 14 ans ou  plus r...  5512000  5975000
#
#        2012     2013     2014     2015     2016     2017     2018
# 0    559000   584000   602000   536000   507000   624000   557000
# 1    287000   254000   307000   320000   277000   289000   331000
# 2   1241000  1283000  1273000  1307000  1117000   966000  1184000
# 3    270000   294000   242000   263000   263000   232000   209000
# 4     77000   134000    83000   126000    93000    72000    44000
# 5    314000   401000   405000   349000   387000   403000   361000
# 6    854000   833000   813000   663000   650000   775000   663000
# 7   1731000  1693000  1672000  1602000  1458000  1653000  1337000
# 8    858000   937000   969000   798000   753000  1096000   967000
# 9    306000   372000   195000   245000   186000   210000   166000
# 10   743000   851000   883000  1102000  1210000  1219000  1260000
# 11   754000   702000   720000   775000   610000   672000   710000
# 12   146000   121000   189000   135000   200000   276000   196000
# 13   425000   349000   446000   317000   285000   408000   359000
# 14  1637000  1774000  1938000  1694000  1811000  1960000  1805000
# 15  5309000  4782000  4990000  5240000  4994000  5334000  4882000
# 16  5801000  6033000  5800000  5663000  5473000  5709000  6207000
# 17  4460000  4760000  4620000  4270000  3910000  4230000  4460000
# 18  5826000  5791000  5889000  5556000  5289100  5352000  5807000

# %%
robbery = getYears.iloc[0]
robbery = pd.DataFrame(robbery)
robbery.columns = robbery.iloc[0]
robbery = robbery[1:]


violenceAtHome = getYears.iloc[13]
violenceAtHome = pd.DataFrame(violenceAtHome)
violenceAtHome.columns = violenceAtHome.iloc[0]
violenceAtHome = violenceAtHome[1:]

violenceOutdoor = getYears.loc[[11, 12]]
violenceOutdoor = pd.Series(violenceOutdoor[[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]].sum())


carjacking = getYears.loc[[3, 4, 5]]
carjacking = pd.Series(carjacking[[2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018]].sum())

plt.plot(robbery)
plt.plot(violenceAtHome)
plt.plot(violenceOutdoor)
plt.plot(carjacking)

plt.title('Évolution des vols et violences en France', fontsize=18)
plt.xlabel('ANNÉES', fontsize=14)
plt.ylabel('VICTIMES', fontsize=14)
plt.legend(["CAMBRIOLAGE", "VIOLENCE EN MÉNAGE", "VIOLENCE HORS MÉNAGE", "VOLS DE VÉHICULE"], bbox_to_anchor=(1,1), fontsize=18)
plt.show()
